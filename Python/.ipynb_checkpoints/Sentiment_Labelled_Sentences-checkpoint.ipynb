# %% [markdown]
# ## Author Nevena Mitic
#
# This project focuses on deep learning algorithms for Sentiment Labelled Sentences.
# Data used for this project are from UCI Machine Learning Repository "https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences#"
#
# This dataset was created for the Paper 'From Group to Individual Labels using Deep Features', Kotzias et. al,. KDD 2015
#
# It contains sentences labelled with positive or negative sentiment, extracted from reviews of products, movies, and restaurants
#
# ### Format
#
# sentence \t score \n
#
#
# ### Details:
# Score is either 1 (for positive) or 0 (for negative)
# The sentences come from three different websites/fields:
#
# imdb.com
# amazon.com
# yelp.com
#
# For each website, there exist 500 positive and 500 negative sentences. Those were selected randomly for larger datasets of reviews.

# %% [markdown]
# ### Read, pre-process and Merge Data

# %%
import pandas as pd
import numpy as np

def rename_columns(data, col1, col2):
    {
        data.rename(
          columns={
            0 : col1,
            1 : col2
        },
          inplace=True
        )
    }


file1 = "C:/Users/Ivan/Desktop/TensorFlow/sentiment labelled sentences/sentiment labelled sentences/amazon_cells_labelled.txt"
file2 = "C:/Users/Ivan/Desktop/TensorFlow/sentiment labelled sentences/sentiment labelled sentences/imdb_labelled.txt"
file3 = "C:/Users/Ivan/Desktop/TensorFlow/sentiment labelled sentences/sentiment labelled sentences/yelp_labelled.txt"
amazon_data = pd.read_csv(file1, sep='\t+', header=None, engine='python')
imdb_data = pd.read_csv(file2, sep='\t+', header=None, engine='python')
yelp_data =  pd.read_csv(file3, sep='\t+', header=None, engine='python')

# rename columns
rename_columns(amazon_data,'sentence', 'label')
rename_columns(imdb_data,'sentence', 'label')
rename_columns(yelp_data,'sentence', 'label')

#print(amazon_data.head(5))

#amazon_data.dtypes
all_data = pd.concat([amazon_data, imdb_data, yelp_data])

all_data.shape
sentences = all_data.values[:,0]
labels = all_data.values[:,1]

# %% [markdown]
# ### Split Data into training and testing sets

# %%
training_size = 2100

training_sentences = sentences[0:training_size]
testing_sentences = sentences[training_size:]
training_labels = labels[0:training_size]
testing_labels = labels[training_size:]

# %%
#!pip install tensorflow==2.0.0
import tensorflow as tf

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
vocab_size = 100
embedding_dim = 32
max_length = 120
trunc_type='post'
padding_type='post'
oov_tok = "<OOV>"

tokenizer = Tokenizer(num_words=vocab_size, oov_token=oov_tok)
tokenizer.fit_on_texts(training_sentences)

word_index = tokenizer.word_index

training_sequences = tokenizer.texts_to_sequences(training_sentences)
training_padded = pad_sequences(training_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

testing_sequences = tokenizer.texts_to_sequences(testing_sentences)
testing_padded = pad_sequences(testing_sequences, maxlen=max_length, padding=padding_type, truncating=trunc_type)

model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

#lr_schedule = tf.keras.callbacks.LearningRateScheduler(
#    lambda epoch: 1e-8 * 10**(epoch / 20))
#optimizer = tf.keras.optimizers.SGD(lr=1e-8, momentum=0.9)

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 120, 32)           3200
# _________________________________________________________________
# bidirectional (Bidirectional (None, 64)                16640
# _________________________________________________________________
# dense (Dense)                (None, 24)                1560
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 21,425
# Trainable params: 21,425
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 25
training_padded = np.array(training_padded)
training_labels = np.array(training_labels)
testing_padded = np.array(testing_padded)
testing_labels = np.array(testing_labels)
history = model.fit(training_padded, training_labels, epochs=num_epochs,
                    validation_data=(testing_padded, testing_labels), verbose=1)
# Out:
# Train on 2100 samples, validate on 900 samples
# Epoch 1/25
# 2100/2100 [==============================] - 7s 3ms/sample - loss: 0.6914 - accuracy: 0.5371 - val_loss: 0.6860 - val_accuracy: 0.6111
# Epoch 2/25
# 2100/2100 [==============================] - 5s 3ms/sample - loss: 0.6315 - accuracy: 0.6490 - val_loss: 0.6109 - val_accuracy: 0.6600
# Epoch 3/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.5588 - accuracy: 0.7019 - val_loss: 0.5802 - val_accuracy: 0.6611
# Epoch 4/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.5401 - accuracy: 0.7105 - val_loss: 0.5704 - val_accuracy: 0.6889
# Epoch 5/25
# 2100/2100 [==============================] - 5s 3ms/sample - loss: 0.5316 - accuracy: 0.7152 - val_loss: 0.5656 - val_accuracy: 0.6767
# Epoch 6/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.5271 - accuracy: 0.7152 - val_loss: 0.5668 - val_accuracy: 0.6689
# Epoch 7/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.5215 - accuracy: 0.7257 - val_loss: 0.5646 - val_accuracy: 0.6800
# Epoch 8/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.5157 - accuracy: 0.7376 - val_loss: 0.5678 - val_accuracy: 0.6744
# Epoch 9/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.5160 - accuracy: 0.7419 - val_loss: 0.5712 - val_accuracy: 0.6567
# Epoch 10/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.5148 - accuracy: 0.7281 - val_loss: 0.5687 - val_accuracy: 0.6600
# Epoch 11/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.5068 - accuracy: 0.7405 - val_loss: 0.5706 - val_accuracy: 0.6711
# Epoch 12/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.5018 - accuracy: 0.7395 - val_loss: 0.5843 - val_accuracy: 0.6756
# Epoch 13/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.5046 - accuracy: 0.7381 - val_loss: 0.5745 - val_accuracy: 0.6722
# Epoch 14/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.5016 - accuracy: 0.7381 - val_loss: 0.5742 - val_accuracy: 0.6678
# Epoch 15/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.4990 - accuracy: 0.7386 - val_loss: 0.5750 - val_accuracy: 0.6811
# Epoch 16/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.4954 - accuracy: 0.7538 - val_loss: 0.5776 - val_accuracy: 0.6667
# Epoch 17/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.4925 - accuracy: 0.7500 - val_loss: 0.6049 - val_accuracy: 0.6511
# Epoch 18/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.4917 - accuracy: 0.7419 - val_loss: 0.5757 - val_accuracy: 0.6633
# Epoch 19/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.4869 - accuracy: 0.7490 - val_loss: 0.5822 - val_accuracy: 0.6589
# Epoch 20/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.4900 - accuracy: 0.7538 - val_loss: 0.5671 - val_accuracy: 0.6789
# Epoch 21/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.4817 - accuracy: 0.7548 - val_loss: 0.5761 - val_accuracy: 0.6667
# Epoch 22/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.4772 - accuracy: 0.7586 - val_loss: 0.5778 - val_accuracy: 0.6733
# Epoch 23/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.4774 - accuracy: 0.7614 - val_loss: 0.5785 - val_accuracy: 0.6667
# Epoch 24/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.4675 - accuracy: 0.7576 - val_loss: 0.6124 - val_accuracy: 0.6500
# Epoch 25/25
# 2100/2100 [==============================] - 6s 3ms/sample - loss: 0.4669 - accuracy: 0.7529 - val_loss: 0.5839 - val_accuracy: 0.6778

# %% [markdown]
# ### Evaluate Model

# %%
# Evaluate model
scores = model.evaluate(testing_padded, testing_labels, verbose=0)
print("Accuracy: %.2f%%" % (scores[1]*100))
# Out:
# Accuracy: 67.78%

# %%
import matplotlib.pyplot as plt

def plot_graphs(history, string):
  plt.plot(history.history[string])
  plt.plot(history.history['val_'+string])
  plt.xlabel("Epochs")
  plt.ylabel(string)
  plt.legend([string, 'val_'+string])
  plt.show()

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')

# %% [markdown]
# ### Summary

# %% [markdown]
#  - In Read data section, loaded data from three files and merged all data into one dataframe.
#  - In split data section, created train and test data (ratio 70:30)
#  - Built LSTM network
#  - Trained for 25 epochs and reached accuracy 67.78

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32, return_sequences=True)),
    tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(32)),
    tf.keras.layers.Dense(24, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()

num_epochs = 10
history = model.fit(training_padded, training_labels, epochs=num_epochs,
                    validation_data=(testing_padded, testing_labels), verbose=1)

plot_graphs(history, 'accuracy')
plot_graphs(history, 'loss')
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_3 (Embedding)      (None, 120, 32)           3200
# _________________________________________________________________
# bidirectional_5 (Bidirection (None, 120, 64)           16640
# _________________________________________________________________
# bidirectional_6 (Bidirection (None, 64)                24832
# _________________________________________________________________
# dense_6 (Dense)              (None, 24)                1560
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 25
# =================================================================
# Total params: 46,257
# Trainable params: 46,257
# Non-trainable params: 0
# _________________________________________________________________
# Train on 2100 samples, validate on 900 samples
# Epoch 1/10
# 2100/2100 [==============================] - 20s 9ms/sample - loss: 0.6928 - accuracy: 0.5086 - val_loss: 0.6889 - val_accuracy: 0.5622
# Epoch 2/10
# 2100/2100 [==============================] - 16s 8ms/sample - loss: 0.6544 - accuracy: 0.6443 - val_loss: 0.6393 - val_accuracy: 0.6133
# Epoch 3/10
# 2100/2100 [==============================] - 13s 6ms/sample - loss: 0.6049 - accuracy: 0.6733 - val_loss: 0.6380 - val_accuracy: 0.6011
# Epoch 4/10
# 2100/2100 [==============================] - 12s 6ms/sample - loss: 0.5812 - accuracy: 0.6867 - val_loss: 0.6109 - val_accuracy: 0.6511
# Epoch 5/10
# 2100/2100 [==============================] - 16s 7ms/sample - loss: 0.5546 - accuracy: 0.7071 - val_loss: 0.6293 - val_accuracy: 0.6444
# Epoch 6/10
# 2100/2100 [==============================] - 15s 7ms/sample - loss: 0.5468 - accuracy: 0.7062 - val_loss: 0.5931 - val_accuracy: 0.6567
# Epoch 7/10
# 2100/2100 [==============================] - 12s 6ms/sample - loss: 0.5320 - accuracy: 0.7190 - val_loss: 0.5765 - val_accuracy: 0.6700
# Epoch 8/10
# 2100/2100 [==============================] - 12s 6ms/sample - loss: 0.5258 - accuracy: 0.7238 - val_loss: 0.5866 - val_accuracy: 0.6622
# Epoch 9/10
# 2100/2100 [==============================] - 11s 5ms/sample - loss: 0.5202 - accuracy: 0.7267 - val_loss: 0.5812 - val_accuracy: 0.6711
# Epoch 10/10
# 2100/2100 [==============================] - 12s 6ms/sample - loss: 0.5214 - accuracy: 0.7214 - val_loss: 0.5717 - val_accuracy: 0.6667
